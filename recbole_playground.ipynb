# %% [markdown]
# <a href="https://colab.research.google.com/github/Lausti98/bsc-recsys/blob/main/recbole_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install recbole
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 85.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 38.9 MB/s eta 0:00:00
# ...

# %%
from recbole.quick_start import run_recbole

run_recbole(model='PNN', dataset='ml-100k')
# Out:
# ...
# Evaluate   : 100%|████████████████████████████████████████████████████| 3/3 [00:00<00:00, 31.68it/s]
# {'best_valid_score': 0.7821,
#  'valid_score_bigger': True,
#  'best_valid_result': OrderedDict([('auc', 0.7821), ('logloss', 0.5651)]),
#  'test_result': OrderedDict([('auc', 0.7844), ('logloss', 0.5623)])}

# %%
from recbole.model.general_recommender.itemknn import ItemKNN
from recbole.evaluator.metrics import NDCG
from recbole.data.dataset import Dataset
from recbole.data.dataloader import TrainDataLoader
